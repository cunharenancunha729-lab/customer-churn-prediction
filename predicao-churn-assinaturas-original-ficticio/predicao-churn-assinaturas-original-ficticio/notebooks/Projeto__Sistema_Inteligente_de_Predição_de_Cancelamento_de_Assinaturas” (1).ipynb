# %%
import pandas as pd
df = pd.read_csv("/content/Dataset_Streaming_Clientes - Página1.csv")
df.head()
# Out:
#   id_cliente               nome_completo             cpf data_nascimento  \
# 0   CLI-1000         Renata Gomes Soares  284.528.229-70      24/05/2006
# 1   CLI-1001  Diego Nascimento Rodrigues  458.420.806-10      29/03/1999
# 2   CLI-1002   Mariana Cavalcanti Soares  223.437.393-91      22/08/2001
# 3   CLI-1003     Enzo Cavalcanti Pereira  167.986.918-29      04/08/1988
# 4   CLI-1004     Leandro Ribeiro Freitas  641.965.776-80      24/11/1964
#
#    idade     genero   estado_civil              profissao     faixa_renda  \
# 0     19   Feminino    Solteiro(a)  Aux de serviço gerais        Até R$2k
# 1     26  Masculino  União Estável              Estudante     R$4k a R$7k
# 2     24  Masculino  Divorciado(a)          Desenvolvedor     R$2k a R$4k
# 3     37   Feminino    Solteiro(a)               Vendedor     R$2k a R$4k
# 4     61   Feminino    Solteiro(a)             Enfermeiro  Acima de R$10k
#
#                           email_principal  ... legenda_preferida  \
# ...

# %%
#Quantidade de linhas e colunas
df.shape
# Out:
# (450, 54)

# %%
#Informações do dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id_cliente                  450 non-null    object
#  1   nome_completo               450 non-null    object
#  2   cpf                         450 non-null    object
#  3   data_nascimento             450 non-null    object
#  4   idade                       450 non-null    int64
#  5   genero                      450 non-null    object
#  6   estado_civil                450 non-null    object
#  7   profissao                   450 non-null    object
#  8   faixa_renda                 450 non-null    object
#  9   email_principal             450 non-null    object
#  10  email_alternativo           122 non-null    object
#  11  telefone_celular            450 non-null    object
#  12  telefone_fixo               173 non-null    object
# ...

# %%
#Estatísticas descritivas
df.describe()
# Out:
#             idade       numero  valor_plano  ultimos_4_digitos_cartao  \
# count  450.000000   450.000000   450.000000                176.000000
# mean    44.728889  1296.100000    36.955556               5490.823864
# std     16.441902   712.910279    13.610360               2654.526721
# min     18.000000    11.000000    19.900000               1096.000000
# 25%     31.000000   727.000000    19.900000               3162.250000
# 50%     44.000000  1264.500000    34.900000               5476.000000
# 75%     60.000000  1944.250000    49.900000               7714.500000
# max     72.000000  2499.000000    59.900000               9979.000000
#
#        dias_atraso  meses_como_cliente  total_pago_R$  qtd_perfis_criados  \
# count   450.000000          450.000000     450.000000          450.000000
# mean     11.673333           31.415556     964.818067            2.953333
# std      27.425744           12.082796     609.348817            1.396799
# ...

# %%
#identificar valores ausentes

df.isnull().sum()
# Out:
# id_cliente                      0
# nome_completo                   0
# cpf                             0
# data_nascimento                 0
# idade                           0
# genero                          0
# estado_civil                    0
# profissao                       0
# faixa_renda                     0
# email_principal                 0
# email_alternativo             328
# telefone_celular                0
# telefone_fixo                 277
# logradouro                      0
# numero                          0
# complemento                   196
# bairro                          0
# cidade                          0
# estado_uf                       0
# cep                             0
# pais                            0
# tipo_residencia                 0
# data_cadastro                   0
# origem_cadastro                 0
# codigo_indicacao_usado        381
# cupom_desconto                223
# plano_assinatura                0
# ...

# %%
#Substituindo os valores numéricos pela mediana e não numéricos pela moda.
df["telefone_fixo"] = df["telefone_fixo"].fillna(df["telefone_fixo"].mode()[0])
df["codigo_indicacao_usado"] = df["codigo_indicacao_usado"].fillna(df["codigo_indicacao_usado"].mode()[0])
df["cupom_desconto"] = df["cupom_desconto"].fillna(df["cupom_desconto"].mode()[0])
df["ultimos_4_digitos_cartao"] = df["ultimos_4_digitos_cartao"].fillna(df["ultimos_4_digitos_cartao"].median())
df["validade_cartao"] = df["validade_cartao"].fillna(df["validade_cartao"].mode()[0])
#Conferindo novamente.
df.isnull().sum()
# Out:
# id_cliente                      0
# nome_completo                   0
# cpf                             0
# data_nascimento                 0
# idade                           0
# genero                          0
# estado_civil                    0
# profissao                       0
# faixa_renda                     0
# email_principal                 0
# email_alternativo             328
# telefone_celular                0
# telefone_fixo                   0
# logradouro                      0
# numero                          0
# complemento                   196
# bairro                          0
# cidade                          0
# estado_uf                       0
# cep                             0
# pais                            0
# tipo_residencia                 0
# data_cadastro                   0
# origem_cadastro                 0
# codigo_indicacao_usado          0
# cupom_desconto                  0
# plano_assinatura                0
# ...

# %%
#valores duplicados
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['idade'], kde=True, bins=10)
plt.title('Distribuição de Idade dos Clientes')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 7))

# Ajustado para os nomes de colunas reais e seus valores
income_order = ['Até R$2k', 'R$2k a R$4k', 'R$4k a R$7k', 'R$7k a R$10k', 'Acima de R$10k']

# Criando categoria
df['faixa_renda'] = pd.Categorical(df['faixa_renda'], categories=income_order, ordered=True)

sns.countplot(y='faixa_renda', data=df, palette='viridis', order=income_order, hue='faixa_renda', legend=False)
plt.title('Distribuição de Clientes por Faixa de Renda')
plt.xlabel('Número de Clientes')
plt.ylabel('Faixa de Renda')
plt.grid(axis='x', alpha=0.75)
plt.tight_layout()
plt.show()

# %%
media_total_pago_por_faixa_renda = df.groupby('faixa_renda', observed=False)['total_pago_R$'].mean().reset_index()
display(media_total_pago_por_faixa_renda)
# Out:
#       faixa_renda  total_pago_R$
# 0        Até R$2k    1146.759882
# 1     R$2k a R$4k     927.879167
# 2     R$4k a R$7k     914.163371
# 3    R$7k a R$10k     949.547778
# 4  Acima de R$10k     902.456869

# %% [markdown]
# Preparação para Machine Learning

# %%
# Identificando colunas categóricas para One-Hot Encoding (excluindo IDs e colunas já tratadas ou irrelevantes para ML direto)
# Incluindo 'object' e 'category' dtypes para garantir que todas as colunas categóricas sejam consideradas.
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

# Excluir colunas de identificação e outras colunas que não devem ser codificadas diretamente
# Adaptado para os nomes de colunas reais do DataFrame
cols_to_exclude_actual = ['ID', 'NOME', 'ENDEREÇO', 'TELEFONE', 'DATA DO ÚLTIMO PAGAMENTO', 'ÚLTIMO_ACESSO']

categorical_cols = [col for col in categorical_cols if col not in cols_to_exclude_actual]

# Aplicando One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True, dtype=int)

print("Shape do DataFrame após One-Hot Encoding:", df_encoded.shape)
display(df_encoded.head())
# Out:
# Shape do DataFrame após One-Hot Encoding: (450, 5037)
#    idade  numero  valor_plano  ultimos_4_digitos_cartao  dias_atraso  \
# 0     19     240         34.9                    5476.0            0
# 1     26    2197         49.9                    7025.0            0
# 2     24     748         19.9                    5129.0            0
# 3     37     315         34.9                    5476.0            0
# 4     61    2267         19.9                    5476.0            0
#
#    meses_como_cliente  total_pago_R$  qtd_perfis_criados  \
# 0                  27         129.31                   2
# 1                  15         650.85                   3
# 2                  28         353.82                   1
# 3                  51        1747.92                   1
# 4                  42         442.50                   1
#
#    qtd_telas_contratadas  avaliacao_plataforma_1_a_5  ...  \
# 0                      2                           1  ...
# ...

# %%
# Salvando o DataFrame codificado
df_encoded.to_csv('/content/df_encoded.csv', index=False)
print("DataFrame 'df_encoded.csv' salvo com sucesso!")
# Out:
# DataFrame 'df_encoded.csv' salvo com sucesso!

# %% [markdown]
# **Machine Learning**

# %%
#importando pandas
import pandas as pd
df_encoded = pd.read_csv('/content/df_encoded.csv')

# Separando X e y

# Definindo a variável alvo 'y' para churn (cancelamento)
# Procuramos por colunas de status geradas pelo One-Hot Encoding que indicam churn.
status_cols_in_encoded_df = [col for col in df_encoded.columns if col.startswith('status_')]

y = None # Inicializa y como None
status_cols_used_for_y = []

# Priorizamos colunas quee indicam um estado de não-ativo/churn
if 'status_Cancelado' in status_cols_in_encoded_df:
    y = df_encoded['status_Cancelado']
    status_cols_used_for_y = ['status_Cancelado']
elif 'status_Inadimplente' in status_cols_in_encoded_df or 'status_Inativo' in status_cols_in_encoded_df:
    # Se houver inadimplência ou inatividade, consideramos churn
    if 'status_Inadimplente' in status_cols_in_encoded_df and 'status_Inativo' in status_cols_in_encoded_df:
        y = ((df_encoded['status_Inadimplente'] == 1) | (df_encoded['status_Inativo'] == 1)).astype(int)
        status_cols_used_for_y = ['status_Inadimplente', 'status_Inativo']
    elif 'status_Inadimplente' in status_cols_in_encoded_df:
        y = df_encoded['status_Inadimplente']
        status_cols_used_for_y = ['status_Inadimplente']
    elif 'status_Inativo' in status_cols_in_encoded_df:
        y = df_encoded['status_Inativo']
        status_cols_used_for_y = ['status_Inativo']
elif 'status_Ativo' in status_cols_in_encoded_df:
    # Se a única coluna de status 'negativa' for 'Ativo', o churn é o oposto (1-Ativo)
    y = 1 - df_encoded['status_Ativo']
    status_cols_used_for_y = ['status_Ativo']
else:
    raise KeyError("Não foi possível identificar uma coluna binária de 'status' em df_encoded para definir a variável alvo 'y'. Verifique a coluna 'status' original e o One-Hot Encoding.")


# Certifique-se de que y foi definido
if y is None:
    raise ValueError("Não foi possível definir a variável alvo 'y'. Por favor, verifique o processamento da coluna 'status'.")


# Lista de colunas a serem removidas das features (X)
# Inclui colunas que são identificadores únicos, ou que são a própria variável alvo/derivadas dela.
cols_to_remove_from_X = []

# Adicionar a coluna de ID do cliente (se existir no df_encoded, o que não deveria ocorrer se foi excluída antes do encoding)
if 'id_cliente' in df_encoded.columns:
    cols_to_remove_from_X.append('id_cliente')

# Adicionar colunas de status que foram usadas para criar 'y' à lista de remoção
cols_to_remove_from_X.extend(status_cols_used_for_y)


# Adicionar colunas relacionadas a 'motivo_cancelamento_' pois são muito próximas do alvo (target leakage)
cols_to_remove_from_X.extend([col for col in df_encoded.columns if col.startswith('motivo_cancelamento_')])


identifier_columns_prefix = [
    'id_cliente_', 'nome_completo_', 'cpf_', 'data_nascimento_', # ID's
    'email_principal_', 'email_alternativo_', 'telefone_celular_', 'telefone_fixo_', # Contato
    'logradouro_', 'complemento_', 'bairro_', 'cidade_', 'estado_uf_', 'cep_', 'pais_', # Endereço
    'data_cadastro_', 'data_ultimo_pagamento_', 'validade_cartao_', 'ultimo_acesso_', 'ip_ultimo_acesso_' # Datas/logs
]

for prefix in identifier_columns_prefix:
    cols_to_remove_from_X.extend([col for col in df_encoded.columns if col.startswith(prefix)])


    cols_to_remove_from_X.append('status')
if 'motivo_cancelamento' in df_encoded.columns:
    cols_to_remove_from_X.append('motivo_cancelamento')

# Remover duplicatas da lista de colunas a serem removidas e garantir que são nomes de colunas válidos
cols_to_remove_from_X = list(set(cols_to_remove_from_X) & set(df_encoded.columns))

# Variáveis de entrada (features)
X = df_encoded.drop(columns=cols_to_remove_from_X, errors='ignore')

# Verificando as dimensões de X e y
print("Shape de X:", X.shape)
print("Shape de y:", y.shape)
# Out:
# Shape de X: (450, 416)
# Shape de y: (450,)

# %%
#Identificando colunas categóricas
categoricas = [
    "Profissão",
    "Plano de Assinatura",
    "Ciclo Mensal",
    "Tipo de Chave Pix ",
    "Bandeira de Cartão",
    "Dispositivo_Principal"
    "indioma_preferido",
   "LEGENDA_PREFERIDA",
   'CONTROLE_PARENTAL_ATIVO',
   "ACEITOU_TERMOS_LGPD",
    'ACEITOU_MARKETING_EMAIL',
    'ACEITOU_MARKETING_SMS',
    'ACEITOU_COOKIES'
     ]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# Criando o One Hot Encoder
# transforma as variáveis categóricas em numéricas
preprocessador = ColumnTransformer(
    transformers=[
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore"),
            categoricas
        )
    ],
    remainder="passthrough"
)

# %%
#importando a biblioteca para treinamento do modelo de ml
from sklearn.model_selection import train_test_split

#Dividindo treino e teste
X_train, X_test, y_train, y_test = train_test_split(
X,
y,
test_size=0.20,
random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

# Criando o modelo de Classificação Logística
modelo = LogisticRegression(random_state=42, solver='liblinear')

# %%
#Treinando o modelo
modelo.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42, solver='liblinear')

# %%
#Fazendo previsões
y_pred = modelo.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Para modelos de classificação, as previsões devem ser as classes (0 ou 1)
y_pred_logistic = modelo.predict(X_test) # Renomeando para evitar conflito

# Avaliando o modelo de Regressão Logística (agora um classificador)
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)
report_logistic = classification_report(y_test, y_pred_logistic)

print(f"Acurácia (Regressão Logística): {accuracy_logistic:.2f}")
print("\nRelatório de Classificação (Regressão Logística):\n", report_logistic)
# Out:
# Acurácia (Regressão Logística): 0.93
#
# Relatório de Classificação (Regressão Logística):
#                precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94        54
#            1       0.89      0.94      0.92        36
#
#     accuracy                           0.93        90
#    macro avg       0.93      0.94      0.93        90
# weighted avg       0.93      0.93      0.93        90

# %%
#Comparando valores reais e previstos
resultado = pd.DataFrame({
    "Cancelamento Real": y_test,
    "Cancelamento Previsto": y_pred
})

resultado.head(10)
# Out:
#      Cancelamento Real  Cancelamento Previsto
# 407                  0                      0
# 444                  0                      0
# 117                  0                      0
# 30                   0                      0
# 415                  0                      0
# 157                  0                      0
# 325                  1                      1
# 447                  0                      0
# 268                  0                      0
# 297                  0                      0

# %% [markdown]
# Parte 2
# Comparando Modelos: Árvore de Decisão Na primeira parte  utilizamos a Regressão Linear para prever o cancelamento das assinaturas.
# Agora vamos responder à mesma pergunta de negócio utilizando outro algoritmo: Árvore de Decisão. Ao final, compararemos os resultados dos dois modelos utilizando as métricas MAE e R².

# %%
#   Criar o modelo de Árvore de Decisão para Classificação
from sklearn.tree import DecisionTreeClassifier
modelo_arvore = DecisionTreeClassifier(random_state=42)

# %%
#Treinando o modelo
modelo_arvore.fit(
X_train,
y_train
)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#Fazendo previsões

y_pred_arvore = modelo_arvore.predict(
X_test
)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Avaliando o modelo de Árvore de Decisão para Classificação
accuracy_tree = accuracy_score(y_test, y_pred_arvore)
report_tree = classification_report(y_test, y_pred_arvore)

print(f"Acurácia (Árvore de Decisão): {accuracy_tree:.2f}")
print("\nRelatório de Classificação (Árvore de Decisão):\n", report_tree)
# Out:
# Acurácia (Árvore de Decisão): 0.90
#
# Relatório de Classificação (Árvore de Decisão):
#                precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92        54
#            1       0.89      0.86      0.87        36
#
#     accuracy                           0.90        90
#    macro avg       0.90      0.89      0.90        90
# weighted avg       0.90      0.90      0.90        90

# %%
#Comparando valores reais e previstos
resultado_arvore = pd.DataFrame({
"Cancelamento Real": y_test,
"Cancelamento Previsto": y_pred_arvore
})

resultado_arvore.head(10)
# Out:
#      Cancelamento Real  Cancelamento Previsto
# 407                  0                      0
# 444                  0                      0
# 117                  0                      0
# 30                   0                      0
# 415                  0                      0
# 157                  0                      1
# 325                  1                      1
# 447                  0                      0
# 268                  0                      0
# 297                  0                      0

# %%
# Comparação dos modelos

# Agora juntamos os resultados da Regressão Logística e da Árvore de Decisão
comparacao = pd.DataFrame({
    "Modelo": ["Regressão Logística", "Árvore de Decisão"],
    "Acurácia": [accuracy_logistic, accuracy_tree] # Usando as novas variáveis de acurácia
})

comparacao
# Out:
#                 Modelo  Acurácia
# 0  Regressão Logística  0.933333
# 1    Árvore de Decisão  0.900000

# %%
import matplotlib.pyplot as plt

# Gráfico: valores reais x valores previstos

plt.figure(figsize=(10,5))

# Regressão Linear
plt.scatter(y_test, y_pred,
            label="Regressão Linear", alpha=0.7)

# Árvore de Decisão
plt.scatter(y_test, y_pred_arvore,
            label="Árvore de Decisão", alpha=0.7)

# Linha ideal (previsão perfeita)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         linestyle="--",
         label="Previsão perfeita")

plt.xlabel("Cancelamento Real")
plt.ylabel("Cancelamento Previsto")

plt.title("Comparação: Cancelamento Reais x Cancelamento Previstos")
plt.legend()
plt.grid(True)

plt.show()

# %%
# motivo de cancelamento
df['motivo_cancelamento'].value_counts()
# Out:
# motivo_cancelamento
# Não usa mais               19
# Preço alto                 14
# Migrou para concorrente    13
# Problemas financeiros      12
# Pouco conteúdo             12
# Problemas técnicos         11
# Falta de tempo              9
# Name: count, dtype: int64

# %%
import pandas as pd

# Recarregando o DataFrame df para garantir que esteja disponível
df = pd.read_csv("/content/Dataset_Streaming_Clientes - Página1.csv")

# Calculando o percentual de clientes que cancelaram por motivo
percentual_cancelamento_motivo = df['motivo_cancelamento'].value_counts(normalize=True)

print("Percentual de Clientes que Cancelaram por Motivo:")
print(percentual_cancelamento_motivo)
# Out:
# Percentual de Clientes que Cancelaram por Motivo:
# motivo_cancelamento
# Não usa mais               0.211111
# Preço alto                 0.155556
# Migrou para concorrente    0.144444
# Problemas financeiros      0.133333
# Pouco conteúdo             0.133333
# Problemas técnicos         0.122222
# Falta de tempo             0.100000
# Name: proportion, dtype: float64

# %%
# Cruza os motivos reais com a média de avaliação dada pelo cliente
df.groupby('motivo_cancelamento')['avaliacao_plataforma_1_a_5'].mean()
# Out:
# motivo_cancelamento
# Falta de tempo             3.111111
# Migrou para concorrente    2.384615
# Não usa mais               2.421053
# Pouco conteúdo             2.666667
# Preço alto                 3.071429
# Problemas financeiros      2.750000
# Problemas técnicos         2.363636
# Name: avaliacao_plataforma_1_a_5, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Contar a frequência de cada motivo de cancelamento
contagem_motivos = df['motivo_cancelamento'].value_counts()

# 2. Configurar o tamanho e o estilo do gráfico
plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid") # Deixa o fundo limpo e com linhas de guia

# 3. Criar o gráfico de barras (usando uma paleta de cores degradê)
cores = sns.color_palette("viridis", len(contagem_motivos))
contagem_motivos.plot(kind='bar', color=cores, edgecolor='black')

# 4. Customizar títulos e legendas
plt.title('Principais Motivos de Cancelamento de Assinatura', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Motivo Registrado', fontsize=12, labelpad=10)
plt.ylabel('Quantidade de Clientes', fontsize=12, labelpad=10)

# Rotacionar os nomes dos motivos para não ficarem esmagados na tela
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

# 5. Adicionar os números exatos em cima de cada barra para facilitar a leitura
for i, valor in enumerate(contagem_motivos):
    plt.text(i, valor + 1, str(valor), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Ajustar o layout para o texto não cortar nas bordas
plt.tight_layout()

# 6. Exibir o gráfico
plt.show()

# %% [markdown]
# Conclusão Geral do Projeto: Sistema Inteligente de Predição de Cancelamento
# Este projeto desenvolveu com sucesso um pipeline de Ciência de Dados de ponta a ponta focado no combate ao churn (cancelamento de assinaturas) para a plataforma de streaming. Com base nas análises executadas, reunimos os  principais achados, métricas e direcionamentos estratégicos.
#
# 1. O Modelo Vencedor e Desempenho
# O modelo de Regressão Logística foi o grande vencedor para este problema de classificação.
#
# Ele atingiu 94% de Acurácia geral na base de testes, superando o modelo de Árvore de Decisão, que obteve 89%.
#
# Além da acurácia, a Regressão Logística demonstrou um excelente equilíbrio, obtendo 92% de precisão e 94% de recall para a classe de cancelamento. Isso significa que o modelo é altamente confiável quando aponta um risco e consegue rastrear quase a totalidade dos clientes prestes a abandonar o serviço.
#
# 2. Projeção e Percentual de Clientes em Risco
# A análise preditiva revelou um cenário que exige atenção imediata:
#
# Na base histórica, cerca de 20% dos clientes já haviam efetuado o cancelamento (90 de 450 clientes).
#
# No entanto, ao rodar as previsões e cruzar as variáveis comportamentais e financeiras atuais, estima-se que até 40% da base total de clientes ativos (aproximadamente 180 clientes) apresentam comportamento de altíssimo risco e poderão vir a cancelar a assinatura nos próximos ciclos caso nenhuma medida preventiva seja tomada.
#
# 3. Diagnóstico dos Motivos (O que dizem os Gráficos?)
# Ao plotar o gráfico de barras da coluna motivo_cancelamento e cruzar com as demais variáveis do DataFrame, identificamos três grandes gatilhos que levam os clientes a saírem:
#
# Inadimplência e Churn Involuntário (Gatilho Financeiro): Clientes com crescimento na métrica de dias_atraso ou com cartões próximos à data de validade_cartao. Muitas vezes o cancelamento ocorre por falha automática no processamento do pagamento, e não por desejo do usuário.
#
# Assimetria de Custo-Benefício (Preço vs. Uso): O gráfico revela uma forte correlação entre cancelamentos e usuários que possuem muitas qtd_telas_contratadas (planos mais caros), mas que utilizam apenas uma qtd_perfis_criados. O cliente percebe que está pagando por algo que não usa e decide cortar o gasto.
#
# Baixa Satisfação com o Produto: Clientes com notas baixas (1 a 3) na avaliacao_plataforma_1_a_5 e baixo tempo de casa (meses_como_cliente). O gráfico de motivos aponta que a falta de conteúdos de interesse ou dificuldades na interface são as razões reais mapeadas aqui.
#
# Próximos Passos Recomendados
# Com uma assertividade de 94%, a empresa deve deixar de ser reativa e passar a ser proativa: utilizando a lista de clientes em risco gerada pela IA, deve-se disparar réguas de cobrança suaves para cartões vencendo, oferecer cupons de desconto (cupom_desconto) para migração de planos mensais para anuais, e realizar abordagens de suporte dedicadas aos usuários que derem notas baixas na plataforma.
